# %%
# Un peu de code python
import matplotlib.pyplot as plt
plt.plot([-2,-1,0,1,2],[4,1,0,1,4],"+")
plt.show()

# %% [markdown]
# # Un titre

# %% [markdown]
# Des consignes:
# * Consigne 1
# * Consigne 2
# * Consigne 3
