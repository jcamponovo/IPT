# %%
from IPython.display import Javascript
timeout = 120 # minutes
Javascript("""let timerId = setInterval(() => IPython.notebook.kernel.execute("a=1"), 300000);
setTimeout(() => { clearInterval(timerId); alert('fin de cession'); },"""+ str(timeout*1000*60)+")")

# %%
Javascript("""Jupyter.actions.call('jupyter-notebook:hide-header')""")

# %%
from ipywidgets import FileUpload, Button, HBox, Layout, Dropdown
from IPython.core.display import HTML
from IPython.display import Javascript
import os
liste = [val for val in os.listdir() if len(val)>6 and val[-6:]==".ipynb" and val!="new.ipynb" and val[0]!="."]

new = 0

bou = Button(
    description='Nouveau',
    disabled=False,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Nouveau',
    icon='' # (FontAwesome names without the `fa-` prefix)
)

bou3 = Dropdown(
    options=liste,
    value="presentation.ipynb",
    description='Ouvrir',
    disabled=False,
)

f = FileUpload(
    description = "Charger",
    accept='.ipynb',  # Accepted file extension e.g. '.txt', '.pdf', 'image/*', 'image/*,.pdf'
    multiple=False  # True to accept multiple files upload else False
)


bou2 = Button(
    description='Terminal',
    disabled=False,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Terminal',
    icon='' # (FontAwesome names without the `fa-` prefix)
)

def change(b):
    display(Javascript('window.open("../notebooks/'+bou3.value+'");'))

    
def on_use(b):
    v = f.value
    if len(v)>6 and v in os.listdir():
        v = v[:-6]+(1)+v[-6:]
    with open(next(iter(f.value)), "w+b") as i:
        i.write(f.data[0])
    os.popen("jupyter trust '{}'".format(next(iter(f.value))))
    url = "../notebooks/"+ next(iter(f.value))
    display(Javascript('window.open("{url}");'.format(url=url)))
    #display(HTML('<a href="../notebooks/note.ipynb">go !</a>'))

def on_click2(b):
    display(Javascript('window.open("../terminals/1");'))
    #display(HTML('<a href="../terminals/1">go !</a>'))
    
def on_click(b):
    global new
    new += 1
    i = open("new.ipynb","r")
    j = open("new{}.ipynb".format(new),"w")
    j.write(i.read())
    i.close()
    j.close()
    url = "../notebooks/new{}.ipynb".format(new)
    display(Javascript('window.open("{url}");'.format(url=url)))
    # display(HTML('<a href="../notebooks/new.ipynb">go !</a>'))
    
bou.on_click(on_click)
bou2.on_click(on_click2)
bou3.observe(change,"value")
f.observe(on_use,"data")
display(HTML("""<h1 style="text-align:center; width:100%;"> Environnement JUPYTER </h1>"""))
display(HBox([bou3,bou,f,bou2],layout=Layout(width="100%",justify_content='center')))
# Out:
# <h1 style="text-align:center; width:100%;"> Environnement JUPYTER </h1>
# HBox(children=(Dropdown(description='Ouvrir', index=4, options=('Untitled.ipynb', 'cours_01_4.ipynb', 'environ…
